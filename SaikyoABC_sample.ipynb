# %%
# %pylab inline
import matplotlib.pyplot as plt
import SaikyoABC as sk
print (sk.__version__)
# Out:
# /Users/iiyama/.virtualenvs/hoge/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')
# Populating the interactive namespace from numpy and matplotlib
# 1.03

# %%
abc = sk.SaikyoABC("strokes.csv")
abc.stroke.ix[10]
# Out:
# STROKE       [[396, 395, 393, 392, 390, 388, 386, 384, 383,...
# Timestamp                           2016-04-20 12:35:16.047000
# PENTYPE                                                 STYLUS
# PENWIDTH                                                     1
# Name: 10, dtype: object

# %%
s = abc.stroke.STROKE[10]
plt.plot(s[0],s[1])

# %%
# PENTYPEがSTYLUSのものだけについて、ストローク長を計算する
lengths = [sk.strokeLength(s) for s,p in zip(abc.stroke.STROKE,abc.stroke.PENTYPE) if p == "STYLUS"]

# %%
plt.plot(lengths)

# %%
import PIL
image = PIL.Image.open("image.gif")
overlayimage = abc.overlay_image(image)
overlayimage
# Out:
# <PIL.Image.Image image mode=RGBA size=2479x3508 at 0x1102F5790>
